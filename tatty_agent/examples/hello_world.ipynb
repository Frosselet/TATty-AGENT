# %% [markdown]
# # 🚀 TATty Agent - Hello World!
#
# **Choose Python 3 kernel** when prompted, then run the cells below step by step.

# %%
# 🔧 Setup - Run this first!
import sys
import os
from pathlib import Path

print("🚀 Setting up TATty Agent...")

# Add repository root to Python path 
current_dir = Path.cwd()
repo_root = current_dir.parent  # Go up from examples/ to repo root

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
    print(f"✅ Added to Python path: {repo_root}")

# Change to repo root for proper imports
os.chdir(repo_root)
print(f"✅ Working directory: {repo_root}")

# Test TATty Agent
try:
    import tatty_agent
    print(f"✅ TATty Agent imported successfully!")
    print(f"📦 Version: {tatty_agent.__version__}")
    
    # Test agent creation
    from tatty_agent import TattyAgent
    agent = TattyAgent(working_dir=".", verbose=False)
    print(f"🤖 Agent ready in: {agent.get_working_dir()}")
    
    print("\n🎉 All set! Continue to next cells...")
    
except Exception as e:
    print(f"❌ Setup failed: {e}")
    print("🔍 Debug info:")
    print(f"  Current dir: {Path.cwd()}")
    print(f"  Repo root: {repo_root}")
    print(f"  TATty exists: {(repo_root / 'tatty_agent').exists()}")

# %% [markdown]
# ## 💬 Basic Usage

# %%
# Ask the agent a simple question
result = agent.ask("What files are in the current directory?")
print(result)

# %% [markdown]
# ## ✨ Magic Commands

# %%
# Load magic commands
# %load_ext tatty_agent.jupyter.magic
print("✅ Magic commands loaded!")

# %%
# Use magic command
# %tatty "Tell me about this TATty Agent project"

# %% [markdown]
# ## 📊 Data Example

# %%
# Create sample data
import pandas as pd

data = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'score': [85, 92, 78]
})

print("📊 Sample data:")
print(data)

# %%
# Ask agent to analyze data
# %tatty "Analyze the 'data' DataFrame and tell me the average score"

# %% [markdown]
# ## 🎉 Success!
#
# You've used TATty Agent to:
# - ✅ Create an AI agent
# - ✅ Ask questions about your project
# - ✅ Use magic commands (`%tatty`)
# - ✅ Analyze data in your notebook
#
# **TATty Agent is ready to help with your projects!** 🚀
